# %% [markdown]
# ### Imports and definitions

# %%
import pandas as pd
import numpy as np
import datetime

# %%
def load_degiro(filename):
    '''
    Reads an export file from DeGiro account (.csv), renames and filters columns.
    Returns: dataframe
    '''
    df = pd.read_csv(filename)
    df = (df.rename(columns={'Datum': 'date', 'Čas': 'time', 'Produkt': 'product',
                  'Reference': 'reference', 'Venue': 'venue',
                  'Počet': 'pcs_change', 'Cena': 'price',
                  'Unnamed: 8': 'price_currency', 'Hodnota': 'value_EUR',
                  'Směnný kurz': 'exchange_rate',
                  'Transaction and/or third': 'transaction_costs_EUR',
                  'Celkem': 'total_EUR', 'ID objednávky': 'ID'})
         .drop(['Hodnota v domácí měně', 'Unnamed: 10', 'Unnamed: 12',
                'Unnamed: 15', 'Unnamed: 17'], axis=1))
    return df

# %%
def process_degiro(df):
    '''
    Formats output from load_degiro() and returns df with unified format.
    Returns: dataframe
    '''
    df['datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'], format='%d-%m-%Y %H:%M')
    df = (df.drop(['date', 'time'], axis=1)
           .set_index('datetime')
           .sort_index()
           .loc[:, ['product', 'ISIN', 'pcs_change', 'value_EUR',
                    'transaction_costs_EUR', 'total_EUR']])
    return df

# %%
def report(df, nISIN, drop=True):
    '''
    Generates final report from processed df (output from process_degiro())
    for specified ISIN.
    
    Input: processed dataframe, ISIN (string)
        drop=True : drop rows where all items were sold before 2021
    
    Returns: dataframe
    '''
    nISIN = '"' + nISIN + '"'
    df1 = df.query(f'ISIN == {nISIN}').sort_index()    
    df1['row_no'] = range(0, df1.shape[0])
    df1['price_per_pc'] = abs(df1['value_EUR'] / df1['pcs_change'])    
    df1['pcs_total'] = df1['pcs_change'].cumsum()
    df1['flag_sell_2021'] = (
        np.where((df1.index.year == 2021)
                 & (df1['pcs_change'] <= 0)
                 & (df1['value_EUR'] != 0),
                 'SELL 2021', ''))
    
    df1['flag_zero'] = np.where((df1['pcs_total'] == 0)
                                & (df1['value_EUR'] != 0),
                                'ALL SOLD', '')    
    
    # drop rows with all items sold before 2021:
    prev = df1.loc[(df1.index.year < 2021)
                   & (df1['pcs_total'] == 0)
                   & (df1['value_EUR'] != 0)].row_no.max()
    if drop and prev > 0:
        df1 = df1.loc[df1['row_no'] > prev]
    
    col_list = ['row_no', 'ISIN', 'product', 'pcs_change', 'pcs_total', 'price_per_pc',
                'value_EUR', 'transaction_costs_EUR', 'total_EUR',
                'flag_sell_2021', 'flag_zero']
    
    return df1.loc[:, col_list]

# %% [markdown]
# ### Load and prepare data

# %%
# file from DeGiro
FILENAME = 'Transactions_2021-12-31_II'  # without extension

ddf = load_degiro(FILENAME + '.csv')
ddf = process_degiro(ddf)
ddf.head(3)
# Out:
#                                     product          ISIN  pcs_change  \
# datetime
# 2016-11-18 09:00:00                  CEZ AS  CZ0005112300         2.0
# 2017-01-10 12:51:00    MONETA MONEY BANK AS  CZ0008040318       250.0
# 2017-01-17 15:30:00  BANK OF AMERICA CORPOR  US0605051046        25.0
#
#                      value_EUR  transaction_costs_EUR  total_EUR
# datetime
# 2016-11-18 09:00:00     -31.23                  -0.77     -32.00
# 2017-01-10 12:51:00    -758.96                  -1.50    -760.46
# 2017-01-17 15:30:00    -529.00                  -0.59    -529.60

# %% [markdown]
# ### Records with NaN transaction costs (head)

# %%
null_df = (ddf[(ddf.transaction_costs_EUR.isna())]
           .sort_values(['datetime', 'ISIN'], ascending=True))
null_df.head()
# Out:
#                                                     product          ISIN  \
# datetime
# 2017-10-05 00:00:00  SIBANYE GOLD LIMITED A - NON TRADEABLE  US8257242060
# 2017-10-16 08:58:00  SIBANYE GOLD LIMITED A - NON TRADEABLE  US8257242060
# 2017-10-16 08:58:00                  SIBANYE GOLD LIMITED A  US8257242060
# 2018-01-30 09:05:00                         ISHARES S&P 500  IE0031442068
# 2018-02-23 16:11:00                         ISHARES S&P 500  IE0031442068
#
#                      pcs_change  value_EUR  transaction_costs_EUR  total_EUR
# datetime
# 2017-10-05 00:00:00         1.0       0.00                    NaN       0.00
# 2017-10-16 08:58:00        -1.0       0.00                    NaN       0.00
# 2017-10-16 08:58:00         1.0       0.00                    NaN       0.00
# 2018-01-30 09:05:00        20.0    -458.60                    NaN    -458.60
# 2018-02-23 16:11:00         5.0    -110.15                    NaN    -110.15

# %% [markdown]
# ### Records with 0 EUR transactions (head)

# %%
zero_EUR_df = ddf[ddf.value_EUR == 0].sort_values(['datetime', 'ISIN'], ascending=True)
zero_EUR_df.head()
# Out:
#                                          product          ISIN  pcs_change  \
# datetime
# 2017-07-31 15:33:00  AMAZON.COM INC. - COM - CFD  US0231351067        -2.0
# 2017-07-31 15:37:00  AMAZON.COM INC. - COM - CFD  US0231351067         2.0
# 2017-07-31 15:59:00  AMAZON.COM INC. - COM - CFD  US0231351067        -2.0
# 2017-07-31 16:12:00  AMAZON.COM INC. - COM - CFD  US0231351067         2.0
# 2017-09-15 16:00:00  AMAZON.COM INC. - COM - CFD  US0231351067        -2.0
#
#                      value_EUR  transaction_costs_EUR  total_EUR
# datetime
# 2017-07-31 15:33:00        0.0                  -0.51      -0.51
# 2017-07-31 15:37:00        0.0                  -0.51      -0.51
# 2017-07-31 15:59:00        0.0                  -0.51      -0.51
# 2017-07-31 16:12:00        0.0                  -0.51      -0.51
# 2017-09-15 16:00:00        0.0                  -0.51      -0.51

# %% [markdown]
# ### All sells in 2021

# %%
c1 = ddf.index.year == 2021
c2 = ddf.pcs_change < 0
all_sells_df = ddf[c1 & c2].sort_values(['datetime', 'ISIN'])

# %% [markdown]
# ### All titles subject to sell in 2021

# %%
titles_df = (all_sells_df[['product','ISIN']]
             .drop_duplicates(subset='ISIN')
             .set_index('ISIN')
             .sort_values('product'))

# %% [markdown]
# ### Volume sold (26 CZK/EUR)

# %%
vol = round(all_sells_df.loc[:, 'value_EUR'].sum()*26)
print(f'Volume sold in 2021: {vol} CZK')
# Out:
# Volume sold in 2021: 416099 CZK

# %% [markdown]
# ### Export data to Excel file

# %%
with pd.ExcelWriter(FILENAME + '_output.xlsx') as writer:
    # list of all sells
    all_sells_df.to_excel(writer, sheet_name='ALL_SELLS_2021')
    
    # list of all titles sold
    titles_df.to_excel(writer, sheet_name='ALL_TITLES')
    
    # all reports in one excel sheet
    df_all = report(ddf, '')  # empty df
    for i in titles_df.index.values:
        df_all = df_all.append(report(ddf, i))
    df_all.to_excel(writer, sheet_name='ONE_SHEET')
    
    # separate sheet for each title
    for i in titles_df.index.values:
        report(ddf, i).to_excel(writer, sheet_name=i)

# %% [markdown]
# ### Show all data

# %%
#for i in titles_df.index.values:
#    display(report(ddf, i))

# %% [markdown]
# ### Show data - Moneta Money Bank

# %%
display(report(ddf, 'CZ0008040318'))
# Out:
#                      row_no          ISIN  \
# datetime
# 2017-04-12 11:19:00       9  CZ0008040318
# 2017-07-03 09:00:00      10  CZ0008040318
# 2017-07-03 09:00:00      11  CZ0008040318
# 2017-07-03 09:00:00      12  CZ0008040318
# 2017-07-03 09:00:00      13  CZ0008040318
# 2018-03-13 10:09:00      14  CZ0008040318
# 2018-11-29 16:25:00      15  CZ0008040318
# 2019-07-26 11:06:00      16  CZ0008040318
# 2019-07-26 11:26:00      17  CZ0008040318
# 2019-11-29 10:51:00      18  CZ0008040318
# 2019-12-13 09:00:00      19  CZ0008040318
# 2020-01-15 10:13:00      20  CZ0008040318
# 2020-02-05 11:04:00      21  CZ0008040318
# 2020-02-27 09:00:00      22  CZ0008040318
# 2020-02-27 09:00:00      23  CZ0008040318
# 2020-03-18 09:38:00      24  CZ0008040318
# 2020-03-18 09:40:00      25  CZ0008040318
# 2020-05-06 10:09:00      26  CZ0008040318
# 2021-01-25 09:17:00      27  CZ0008040318
# 2021-02-16 00:00:00      28  CZ0008040318
# 2021-02-16 00:00:00      29  CZ0008040318
# 2021-03-24 00:00:00      30  CZ0008040318
# 2021-03-24 00:00:00      31  CZ0008040318
# 2021-03-24 13:52:00      32  CZ0008040318
# 2021-03-24 13:52:00      33  CZ0008040318
#
#                                                   product  pcs_change  \
# datetime
# 2017-04-12 11:19:00                  MONETA MONEY BANK AS       750.0
# 2017-07-03 09:00:00                  MONETA MONEY BANK AS      -175.0
# 2017-07-03 09:00:00                  MONETA MONEY BANK AS      -300.0
# 2017-07-03 09:00:00                  MONETA MONEY BANK AS       -50.0
# 2017-07-03 09:00:00                  MONETA MONEY BANK AS       -25.0
# 2018-03-13 10:09:00                  MONETA MONEY BANK AS      1200.0
# 2018-11-29 16:25:00                  MONETA MONEY BANK AS      -300.0
# 2019-07-26 11:06:00                  MONETA MONEY BANK AS       -33.0
# 2019-07-26 11:26:00                  MONETA MONEY BANK AS      -467.0
# 2019-11-29 10:51:00                  MONETA MONEY BANK AS       320.0
# 2019-12-13 09:00:00                  MONETA MONEY BANK AS      -200.0
# 2020-01-15 10:13:00                  MONETA MONEY BANK AS      -150.0
# 2020-02-05 11:04:00                  MONETA MONEY BANK AS      -160.0
# 2020-02-27 09:00:00                  MONETA MONEY BANK AS      -200.0
# 2020-02-27 09:00:00                  MONETA MONEY BANK AS      -120.0
# 2020-03-18 09:38:00                  MONETA MONEY BANK AS       -15.0
# 2020-03-18 09:40:00                  MONETA MONEY BANK AS        30.0
# 2020-05-06 10:09:00                  MONETA MONEY BANK AS       500.0
# 2021-01-25 09:17:00                  MONETA MONEY BANK AS      -405.0
# 2021-02-16 00:00:00                  MONETA MONEY BANK AS      -200.0
# 2021-02-16 00:00:00  MONETA MONEY BANK AS - NON TRADEABLE       200.0
